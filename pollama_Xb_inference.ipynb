# %% [markdown]
# <a href="https://colab.research.google.com/github/szymonrucinski/finetune-llm/blob/main/pollama_Xb_inference.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/szymonrucinski/finetune-llm/
# !cd finetune-llm/
# !sh finetune-llm/install_deps_llama_2.sh
# Out:
# Cloning into 'finetune-llm'...
# remote: Enumerating objects: 41, done.
# remote: Counting objects: 100% (41/41), done.
# remote: Compressing objects: 100% (40/40), done.
# remote: Total 41 (delta 22), reused 5 (delta 1), pack-reused 0
# Receiving objects: 100% (41/41), 25.04 KiB | 1.93 MiB/s, done.
# Resolving deltas: 100% (22/22), done.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.5/92.5 MB 11.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 18.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 27.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 42.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 39.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 kB 1.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 251.2/251.2 kB 9.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.2/244.2 kB 4.5 MB/s eta 0:00:00
# ...

# %%
MODEL_VERSION='13b'
MODEL_VERSION='7b'

# %%
from peft import PeftModel, PeftConfig
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline
from pprint import pprint

config = PeftConfig.from_pretrained(f"/home/finetune-llm/mistral-polish-llms-adaptive-pretrain/krakowiak-v2-7b-pretrain")
model = AutoModelForCausalLM.from_pretrained(f"mistralai/Mistral-7B-v0.1")

tokenizer = AutoTokenizer.from_pretrained("mistralai/Mistral-7B-v0.1")
model = PeftModel.from_pretrained(model, f"/home/finetune-llm/mistral-polish-llms-adaptive-pretrain/krakowiak-v2-7b-pretrain")

pipeline = pipeline(
    "text-generation",
    model=model,
    device=0,
    tokenizer=tokenizer)
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# ...

# %%
pipeline("Kanapka z ", max_new_tokens=256, temperature=0.6, repetition_penalty=2.0, top_p=0.95)
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# [{'generated_text': 'Kanapka z  Żywego Różańca w Piekarach Śl. Wśród nich była młoda dziewczyna, która szufladkę pewną rzeczy nie mogli znaleźć i poszukiwali jej przez całe wiele godzin - opowiada ojciec Marcin Giersch na temat tzw "szafki śmierci" oraz innych relikwiarza przeznaczony do kultury Bożego Ciało\nWojtek Szewczyński/Radio eM /Piekary-Sklodowice (KAI) Opracował: Krzesimir Dziekanowski Czasami trwa kilku dni albo wraca po latach – ale jest tak samo ważywy jak gdyby to się stało od razem; a czas najbardzo potrzebny dla czynienia świata piotrowymi przeszkładom”. Takim sformulowany wyrazistych treści pisany był list apostolski papieskie „Victiforium” Benedykta XVI dotycz'}]

# %%
import gradio as gr

def greet(query):
    sequences = pipeline(
    f'### Użytkownik: {query} ### Asystent: ',
    # do_sample=True,
    # top_k=10,
    top_p=0.95,
    num_return_sequences=1,
    eos_token_id=tokenizer.eos_token_id,
    max_length=200,
    temperature=0.2,
    repetition_penalty=2.0,
    # length_penalty=-0.5
  )
    for seq in sequences:
      return f"{seq['generated_text']}".split("Asystent:")[1]

# %%
import gradio as gr
import random
import time

with gr.Blocks() as demo:
    chatbot = gr.Chatbot()
    msg = gr.Textbox()
    clear = gr.ClearButton([msg, chatbot])

    def respond(message, chat_history):
        bot_message = greet(message)
        chat_history.append((message, bot_message))
        return "", chat_history

    msg.submit(respond, [msg, chatbot], [msg, chatbot])

demo.launch(share=True)
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# Running on public URL: https://3df7551deb4a1db0db.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://3df7551deb4a1db0db.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
import gradio as gr
import random
import time

with gr.Blocks() as demo:
    chatbot = gr.Chatbot()
    msg = gr.Textbox()
    clear = gr.Button("Clear")

    def user(user_message, history):
        return "", history + [[user_message, None]]

    def bot(history):
        bot_message = greet(history[-1])
        print(history)
        history[-1][1] = ""
        for character in bot_message:
            history[-1][1] += character
            time.sleep(0.03)
            yield history

    msg.submit(user, [msg, chatbot], [msg, chatbot], queue=False).then(
        bot, chatbot, chatbot
    )
    clear.click(lambda: None, None, chatbot, queue=False)

demo.queue()
demo.launch(share=True)
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# Running on public URL: https://10d600ab5bd09a1199.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://10d600ab5bd09a1199.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
model
